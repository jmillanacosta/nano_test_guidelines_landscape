# %% [markdown]
# # Wikidata - OECD TG - Endpoint - Material
#
# https://web-archive.oecd.org/2016-11-07/361917-dossiers-and-endpoints-testing-programme-manufactured-nanomaterials.htm used to find the NMs tested for each endpoint
#
#
# https://www.oecd.org/ehs/templates/harmonised-templates.htm used to find the TGs associated to each endpoint

# %%
def remove_lr_whitespace(text):
    text = str(text).lstrip()
    return text

# %%
import pandas as pd
import numpy as np
import regex as re
import json

# %% [markdown]
# ## Endpoints and tested materials table
# this one we can download directly

# %%
endpoint_material = pd.read_excel('oecd/endpoint_material.xlsx').applymap(remove_lr_whitespace)

endpoint_material.sample()
# Out:
# /tmp/ipykernel_274091/1491708580.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   endpoint_material = pd.read_excel('oecd/endpoint_material.xlsx').applymap(remove_lr_whitespace)
#                ENDPOINTS Fullerenes (C60)  \
# 36  4.6 Vapour pressure               1.0
#
#    Single-walled carbon nanotubes (SWCNTs)  \
# 36                                     nan
#
#    Multi-walled carbon nanotubes (MWCNTs) Silver nanoparticles  \
# 36                                    nan                  1.0
#
#    Titanium dioxide NM105 Titanium dioxide NM100 Titanium dioxide NM101  \
# 36                    1.0                    nan                    1.0
#
#    Titanium dioxide NM102 Titanium dioxide NM103  ... Silicon dioxide NM200   \
# 36                    nan                    1.0  ...                    nan
#
#    Silicon dioxide NM201  Silicon dioxide NM202  Silicon dioxide NM203   \
# 36                    nan                    nan                    nan
#
#    Silicon dioxide NM204   \
# 36                    nan
#
#    Silicon dioxide JP AIST data on SiO2 UFP-80 and NanoTek Dendrimers   \
# 36                                                nan              nan
#
#    Nanoclays  Gold nanoparticles  TOTALS
# 36        nan                 nan    6.0
#
# [1 rows x 23 columns]

# %%
endpoint_material = endpoint_material.drop(columns=["TOTALS"], errors="ignore")

# %% [markdown]
# Which materials?

# %%
endpoint_material.columns
# Out:
# Index(['ENDPOINTS', 'Fullerenes (C60)',
#        'Single-walled carbon nanotubes (SWCNTs)',
#        'Multi-walled carbon nanotubes (MWCNTs)', 'Silver nanoparticles',
#        'Titanium dioxide NM105', 'Titanium dioxide NM100',
#        'Titanium dioxide NM101', 'Titanium dioxide NM102',
#        'Titanium dioxide NM103', 'Titanium dioxide NM104', 'Cerium oxide',
#        'Zinc oxide', 'Silicon dioxide NM200 ', 'Silicon dioxide NM201 ',
#        'Silicon dioxide NM202 ', 'Silicon dioxide NM203 ',
#        'Silicon dioxide NM204 ',
#        'Silicon dioxide JP AIST data on SiO2 UFP-80 and NanoTek',
#        'Dendrimers ', 'Nanoclays ', 'Gold nanoparticles '],
#       dtype='object')

# %%
endpoint_material['ENDPOINTS']
# Out:
# 0                                1. GENERAL INFORMATION
# 1                                     1.1 Identification
# 2                                       1.2 Composition
# 3                                       1.3 Identifiers
# 4                            1.4 Analytical information
#                              ...
# 183    14.3.8 Measures to protect humans, animals and...
# 184          14.3.9 Packaging (12.7 in Annex III of BPR)
# 185                       14.3.10 Summary and evaluation
# 186                                               TOTALS
# 187                                          GRAND TOTAL
# Name: ENDPOINTS, Length: 188, dtype: object

# %% [markdown]
# Need cleanup

# %%
endpoint_material['ENDPOINTS'] = endpoint_material['ENDPOINTS'].str.replace(r'\d+', '', regex=True)
endpoint_material['ENDPOINTS'] = endpoint_material['ENDPOINTS'].str.replace(r'\.', '', regex=True)
endpoint_material['ENDPOINTS']
# Out:
# 0                                   GENERAL INFORMATION
# 1                                         Identification
# 2                                           Composition
# 3                                           Identifiers
# 4                                Analytical information
#                              ...
# 183     Measures to protect humans, animals and the e...
# 184                     Packaging ( in Annex III of BPR)
# 185                               Summary and evaluation
# 186                                               TOTALS
# 187                                          GRAND TOTAL
# Name: ENDPOINTS, Length: 188, dtype: object

# %%
endpoint_material.sample(3)
# Out:
#                                     ENDPOINTS Fullerenes (C60)  \
# 172                 INFORMATION REQUIREMENTS               nan
# 140   Toxicity to reproduction: other studies              nan
# 159            Metabolism in rotational crops              nan
#
#     Single-walled carbon nanotubes (SWCNTs)  \
# 172                                     nan
# 140                                     nan
# 159                                     nan
#
#     Multi-walled carbon nanotubes (MWCNTs) Silver nanoparticles  \
# 172                                    nan                  nan
# 140                                    nan                  nan
# 159                                    nan                  nan
#
#     Titanium dioxide NM105 Titanium dioxide NM100 Titanium dioxide NM101  \
# 172                    nan                    nan                    nan
# 140                    nan                    nan                    nan
# 159                    nan                    nan                    nan
#
#     Titanium dioxide NM102 Titanium dioxide NM103  ... Zinc oxide  \
# 172                    nan                    nan  ...        nan
# 140                    nan                    nan  ...        nan
# 159                    nan                    nan  ...        nan
#
#     Silicon dioxide NM200  Silicon dioxide NM201  Silicon dioxide NM202   \
# 172                    nan                    nan                    nan
# 140                    nan                    nan                    nan
# 159                    nan                    nan                    nan
#
#     Silicon dioxide NM203  Silicon dioxide NM204   \
# 172                    nan                    nan
# 140                    nan                    nan
# 159                    nan                    nan
#
#     Silicon dioxide JP AIST data on SiO2 UFP-80 and NanoTek Dendrimers   \
# 172                                                nan              nan
# 140                                                nan              nan
# 159                                                nan              nan
#
#     Nanoclays  Gold nanoparticles
# 172        nan                 nan
# 140        nan                 nan
# 159        nan                 nan
#
# [3 rows x 22 columns]

# %% [markdown]
# ## Endpoints and TGs
# Retrieved from navigating https://www.oecd.org/ehs/templates/harmonised-templates.htm

# %% [markdown]
# Physchem templates: https://www.oecd.org/ehs/templates/harmonised-templates-physico-chemical-properties.htm
# ![screenshot_physchem_oecd](physchem.png)
#
# The corresponding OECD Test Guidelines are listed in the 5th row

# %%
import numpy as np
endpoints_tg = pd.read_csv('oecd/endpoint_guidelines.csv', sep='\t').applymap(remove_lr_whitespace)
endpoints_tg.sample(1)
# Out:
# /tmp/ipykernel_274091/2253259607.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   endpoints_tg = pd.read_csv('oecd/endpoint_guidelines.csv', sep='\t').applymap(remove_lr_whitespace)
#                                Endpoint Last update  \
# 74  Metabolism of residues in livestock   Jul. 2023
#
#    Corresponding OECD Test Guideline(s)
# 74                                TG503

# %% [markdown]
# Match columns endpoints_tg['Template'] and endpoint_material['ENDPOINT']

# %%
endpoints_tg.columns
# Out:
# Index(['Endpoint', 'Last update', 'Corresponding OECD Test Guideline(s)'], dtype='object')

# %%
seen = []
materials = list(endpoint_material.columns)[1:]
tgs_endpoints_materials = {i: {mat: [] for mat in materials} for i in list(endpoints_tg['Endpoint'])}

for i, rowi in endpoints_tg.iterrows():
    tgs = rowi['Corresponding OECD Test Guideline(s)']
    if tgs != 'none':
        if ',' in tgs:
            tgs = tgs.split(", ")  # Splitting the string correctly
        else:
            tgs = [tgs]
        endpoint_i = rowi['Endpoint']
        if endpoint_i not in seen:
            seen.append(endpoint_i)
            for j, rowj in endpoint_material.iterrows():
                endpoint_j = rowj['ENDPOINTS']
                pattern = re.compile(endpoint_i, re.IGNORECASE)  # No need for parentheses here
                if pattern.search(endpoint_j):
                    tested_mats = [mat for mat in materials if not pd.isnull(rowj[mat])]  # Checking for NaN values
                    for mat in tested_mats:
                        for tg in tgs:
                            tgs_endpoints_materials[endpoint_i][mat].append(tg)  # Using add() to add to a set

print(tgs_endpoints_materials)
# Out:
# {'Water solubility': {'Fullerenes (C60)': ['TG105'], 'Single-walled carbon nanotubes (SWCNTs)': ['TG105'], 'Multi-walled carbon nanotubes (MWCNTs)': ['TG105'], 'Silver nanoparticles': ['TG105'], 'Titanium dioxide NM105': ['TG105'], 'Titanium dioxide NM100': ['TG105'], 'Titanium dioxide NM101': ['TG105'], 'Titanium dioxide NM102': ['TG105'], 'Titanium dioxide NM103': ['TG105'], 'Titanium dioxide NM104': ['TG105'], 'Cerium oxide': ['TG105'], 'Zinc oxide': ['TG105'], 'Silicon dioxide NM200 ': ['TG105'], 'Silicon dioxide NM201 ': ['TG105'], 'Silicon dioxide NM202 ': ['TG105'], 'Silicon dioxide NM203 ': ['TG105'], 'Silicon dioxide NM204 ': ['TG105'], 'Silicon dioxide JP AIST data on SiO2 UFP-80 and NanoTek': ['TG105'], 'Dendrimers ': ['TG105'], 'Nanoclays ': ['TG105'], 'Gold nanoparticles ': ['TG105']}, 'Viscosity': {'Fullerenes (C60)': ['TG114'], 'Single-walled carbon nanotubes (SWCNTs)': ['TG114'], 'Multi-walled carbon nanotubes (MWCNTs)': ['TG114'], 'Silver nanoparticles': ['TG114'], 'Titanium dioxide NM105': ['TG114'], 'Titanium dioxide NM100': ['TG114'], 'Titanium dioxide NM101': ['TG114'], 'Titanium dioxide NM102': ['TG114'], 'Titanium dioxide NM103': ['TG114'], 'Titanium dioxide NM104': ['TG114'], 'Cerium oxide': ['TG114'], 'Zinc oxide': ['TG114'], 'Silicon dioxide NM200 ': ['TG114'], 'Silicon dioxide NM201 ': ['TG114'], 'Silicon dioxide NM202 ': ['TG114'], 'Silicon dioxide NM203 ': ['TG114'], 'Silicon dioxide NM204 ': ['TG114'], 'Silicon dioxide JP AIST data on SiO2 UFP-80 and NanoTek': ['TG114'], 'Dendrimers ': ['TG114'], 'Nanoclays ': ['TG114'], 'Gold nanoparticles ': ['TG114']}, 'Vapour pressure': {'Fullerenes (C60)': ['TG104'], 'Single-walled carbon nanotubes (SWCNTs)': ['TG104'], 'Multi-walled carbon nanotubes (MWCNTs)': ['TG104'], 'Silver nanoparticles': ['TG104'], 'Titanium dioxide NM105': ['TG104'], 'Titanium dioxide NM100': ['TG104'], 'Titanium dioxide NM101': ['TG104'], 'Titanium dioxide NM102': ['TG104'], 'Titanium dioxide NM103': ['TG104'], 'Titanium dioxide NM104': ['TG104'], 'Cerium oxide': ['TG104'], 'Zinc oxide': ['TG104'], 'Silicon dioxide NM200 ': ['TG104'], 'Silicon dioxide NM201 ': ['TG104'], 'Silicon dioxide NM202 ': ['TG104'], 'Silicon dioxide NM203 ': ['TG104'], 'Silicon dioxide NM204 ': ['TG104'], 'Silicon dioxide JP AIST data on SiO2 UFP-80 and NanoTek': ['TG104'], 'Dendrimers ': ['TG104'], 'Nanoclays ': ['TG104'], 'Gold nanoparticles ': ['TG104']}, 'Use and exposure information:Widespread use by professional workers': {'Fullerenes (C60)': [], 'Single-walled carbon nanotubes (SWCNTs)': [], 'Multi-walled carbon nanotubes (MWCNTs)': [], 'Silver nanoparticles': [], 'Titanium dioxide NM105': [], 'Titanium dioxide NM100': [], 'Titanium dioxide NM101': [], 'Titanium dioxide NM102': [], 'Titanium dioxide NM103': [], 'Titanium dioxide NM104': [], 'Cerium oxide': [], 'Zinc oxide': [], 'Silicon dioxide NM200 ': [], 'Silicon dioxide NM201 ': [], 'Silicon dioxide NM202 ': [], 'Silicon dioxide NM203 ': [], 'Silicon dioxide NM204 ': [], 'Silicon dioxide JP AIST data on SiO2 UFP-80 and NanoTek': [], 'Dendrimers ': [], 'Nanoclays ': [], 'Gold nanoparticles ': []}, 'Use and exposure information:Uses at industrial sites': {'Fullerenes (C60)': [], 'Single-walled carbon nanotubes (SWCNTs)': [], 'Multi-walled carbon nanotubes (MWCNTs)': [], 'Silver nanoparticles': [], 'Titanium dioxide NM105': [], 'Titanium dioxide NM100': [], 'Titanium dioxide NM101': [], 'Titanium dioxide NM102': [], 'Titanium dioxide NM103': [], 'Titanium dioxide NM104': [], 'Cerium oxide': [], 'Zinc oxide': [], 'Silicon dioxide NM200 ': [], 'Silicon dioxide NM201 ': [], 'Silicon dioxide NM202 ': [], 'Silicon dioxide NM203 ': [], 'Silicon dioxide NM204 ': [], 'Silicon dioxide JP AIST data on SiO2 UFP-80 and NanoTek': [], 'Dendrimers ': [], 'Nanoclays ': [], 'Gold nanoparticles ': []}, 'Use and exposure information:Service life': {'Fullerenes (C60)': [], 'Single-walled carbon nanotubes (SWCNTs)': [], 'Multi-walled carbon nanotubes (MWCNTs)': [], 'Silv ...

# %%
file_path = "data_tg_material_endpoint.json"

# Write the dictionary to the JSON file
with open(file_path, "w") as json_file:
    json.dump(tgs_endpoints_materials, json_file, indent=2)

# %%
pd.read_json(file_path)
# Out:
#                                                    Water solubility Viscosity  \
# Fullerenes (C60)                                            [TG105]   [TG114]
# Single-walled carbon nanotubes (SWCNTs)                     [TG105]   [TG114]
# Multi-walled carbon nanotubes (MWCNTs)                      [TG105]   [TG114]
# Silver nanoparticles                                        [TG105]   [TG114]
# Titanium dioxide NM105                                      [TG105]   [TG114]
# Titanium dioxide NM100                                      [TG105]   [TG114]
# Titanium dioxide NM101                                      [TG105]   [TG114]
# Titanium dioxide NM102                                      [TG105]   [TG114]
# Titanium dioxide NM103                                      [TG105]   [TG114]
# Titanium dioxide NM104                                      [TG105]   [TG114]
# Cerium oxide                                                [TG105]   [TG114]
# Zinc oxide                                                  [TG105]   [TG114]
# Silicon dioxide NM200                                       [TG105]   [TG114]
# Silicon dioxide NM201                                       [TG105]   [TG114]
# Silicon dioxide NM202                                       [TG105]   [TG114]
# Silicon dioxide NM203                                       [TG105]   [TG114]
# Silicon dioxide NM204                                       [TG105]   [TG114]
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...          [TG105]   [TG114]
# Dendrimers                                                  [TG105]   [TG114]
# Nanoclays                                                   [TG105]   [TG114]
# Gold nanoparticles                                          [TG105]   [TG114]
#
#                                                    Vapour pressure  \
# Fullerenes (C60)                                           [TG104]
# Single-walled carbon nanotubes (SWCNTs)                    [TG104]
# Multi-walled carbon nanotubes (MWCNTs)                     [TG104]
# Silver nanoparticles                                       [TG104]
# Titanium dioxide NM105                                     [TG104]
# Titanium dioxide NM100                                     [TG104]
# Titanium dioxide NM101                                     [TG104]
# Titanium dioxide NM102                                     [TG104]
# Titanium dioxide NM103                                     [TG104]
# Titanium dioxide NM104                                     [TG104]
# Cerium oxide                                               [TG104]
# Zinc oxide                                                 [TG104]
# Silicon dioxide NM200                                      [TG104]
# Silicon dioxide NM201                                      [TG104]
# Silicon dioxide NM202                                      [TG104]
# Silicon dioxide NM203                                      [TG104]
# Silicon dioxide NM204                                      [TG104]
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...         [TG104]
# Dendrimers                                                 [TG104]
# Nanoclays                                                  [TG104]
# Gold nanoparticles                                         [TG104]
#
#                                                    Use and exposure information:Widespread use by professional workers  \
# Fullerenes (C60)                                                                                   []
# Single-walled carbon nanotubes (SWCNTs)                                                            []
# Multi-walled carbon nanotubes (MWCNTs)                                                             []
# Silver nanoparticles                                                                               []
# Titanium dioxide NM105                                                                             []
# Titanium dioxide NM100                                                                             []
# Titanium dioxide NM101                                                                             []
# Titanium dioxide NM102                                                                             []
# Titanium dioxide NM103                                                                             []
# Titanium dioxide NM104                                                                             []
# Cerium oxide                                                                                       []
# Zinc oxide                                                                                         []
# Silicon dioxide NM200                                                                              []
# Silicon dioxide NM201                                                                              []
# Silicon dioxide NM202                                                                              []
# Silicon dioxide NM203                                                                              []
# Silicon dioxide NM204                                                                              []
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...                                                 []
# Dendrimers                                                                                         []
# Nanoclays                                                                                          []
# Gold nanoparticles                                                                                 []
#
#                                                    Use and exposure information:Uses at industrial sites  \
# Fullerenes (C60)                                                                                   []
# Single-walled carbon nanotubes (SWCNTs)                                                            []
# Multi-walled carbon nanotubes (MWCNTs)                                                             []
# Silver nanoparticles                                                                               []
# Titanium dioxide NM105                                                                             []
# Titanium dioxide NM100                                                                             []
# Titanium dioxide NM101                                                                             []
# Titanium dioxide NM102                                                                             []
# Titanium dioxide NM103                                                                             []
# Titanium dioxide NM104                                                                             []
# Cerium oxide                                                                                       []
# Zinc oxide                                                                                         []
# Silicon dioxide NM200                                                                              []
# Silicon dioxide NM201                                                                              []
# Silicon dioxide NM202                                                                              []
# Silicon dioxide NM203                                                                              []
# Silicon dioxide NM204                                                                              []
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...                                                 []
# Dendrimers                                                                                         []
# Nanoclays                                                                                          []
# Gold nanoparticles                                                                                 []
#
#                                                    Use and exposure information:Service life  \
# Fullerenes (C60)                                                                          []
# Single-walled carbon nanotubes (SWCNTs)                                                   []
# Multi-walled carbon nanotubes (MWCNTs)                                                    []
# Silver nanoparticles                                                                      []
# Titanium dioxide NM105                                                                    []
# Titanium dioxide NM100                                                                    []
# Titanium dioxide NM101                                                                    []
# Titanium dioxide NM102                                                                    []
# Titanium dioxide NM103                                                                    []
# Titanium dioxide NM104                                                                    []
# Cerium oxide                                                                              []
# Zinc oxide                                                                                []
# Silicon dioxide NM200                                                                     []
# Silicon dioxide NM201                                                                     []
# Silicon dioxide NM202                                                                     []
# Silicon dioxide NM203                                                                     []
# Silicon dioxide NM204                                                                     []
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...                                        []
# Dendrimers                                                                                []
# Nanoclays                                                                                 []
# Gold nanoparticles                                                                        []
#
#                                                    Use and exposure information:Manufacture  \
# Fullerenes (C60)                                                                         []
# Single-walled carbon nanotubes (SWCNTs)                                                  []
# Multi-walled carbon nanotubes (MWCNTs)                                                   []
# Silver nanoparticles                                                                     []
# Titanium dioxide NM105                                                                   []
# Titanium dioxide NM100                                                                   []
# Titanium dioxide NM101                                                                   []
# Titanium dioxide NM102                                                                   []
# Titanium dioxide NM103                                                                   []
# Titanium dioxide NM104                                                                   []
# Cerium oxide                                                                             []
# Zinc oxide                                                                               []
# Silicon dioxide NM200                                                                    []
# Silicon dioxide NM201                                                                    []
# Silicon dioxide NM202                                                                    []
# Silicon dioxide NM203                                                                    []
# Silicon dioxide NM204                                                                    []
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...                                       []
# Dendrimers                                                                               []
# Nanoclays                                                                                []
# Gold nanoparticles                                                                       []
#
#                                                    Use and exposure information:Formulating or re-packing  \
# Fullerenes (C60)                                                                                   []
# Single-walled carbon nanotubes (SWCNTs)                                                            []
# Multi-walled carbon nanotubes (MWCNTs)                                                             []
# Silver nanoparticles                                                                               []
# Titanium dioxide NM105                                                                             []
# Titanium dioxide NM100                                                                             []
# Titanium dioxide NM101                                                                             []
# Titanium dioxide NM102                                                                             []
# Titanium dioxide NM103                                                                             []
# Titanium dioxide NM104                                                                             []
# Cerium oxide                                                                                       []
# Zinc oxide                                                                                         []
# Silicon dioxide NM200                                                                              []
# Silicon dioxide NM201                                                                              []
# Silicon dioxide NM202                                                                              []
# Silicon dioxide NM203                                                                              []
# Silicon dioxide NM204                                                                              []
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...                                                 []
# Dendrimers                                                                                         []
# Nanoclays                                                                                          []
# Gold nanoparticles                                                                                 []
#
#                                                    Use and exposure information:Consumer uses  \
# Fullerenes (C60)                                                                           []
# Single-walled carbon nanotubes (SWCNTs)                                                    []
# Multi-walled carbon nanotubes (MWCNTs)                                                     []
# Silver nanoparticles                                                                       []
# Titanium dioxide NM105                                                                     []
# Titanium dioxide NM100                                                                     []
# Titanium dioxide NM101                                                                     []
# Titanium dioxide NM102                                                                     []
# Titanium dioxide NM103                                                                     []
# Titanium dioxide NM104                                                                     []
# Cerium oxide                                                                               []
# Zinc oxide                                                                                 []
# Silicon dioxide NM200                                                                      []
# Silicon dioxide NM201                                                                      []
# Silicon dioxide NM202                                                                      []
# Silicon dioxide NM203                                                                      []
# Silicon dioxide NM204                                                                      []
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...                                         []
# Dendrimers                                                                                 []
# Nanoclays                                                                                  []
# Gold nanoparticles                                                                         []
#
#                                                    Toxicity to terrestrial plants  \
# Fullerenes (C60)                                                   [TG208, TG227]
# Single-walled carbon nanotubes (SWCNTs)                            [TG208, TG227]
# Multi-walled carbon nanotubes (MWCNTs)                             [TG208, TG227]
# Silver nanoparticles                                               [TG208, TG227]
# Titanium dioxide NM105                                             [TG208, TG227]
# Titanium dioxide NM100                                             [TG208, TG227]
# Titanium dioxide NM101                                             [TG208, TG227]
# Titanium dioxide NM102                                             [TG208, TG227]
# Titanium dioxide NM103                                             [TG208, TG227]
# Titanium dioxide NM104                                             [TG208, TG227]
# Cerium oxide                                                       [TG208, TG227]
# Zinc oxide                                                         [TG208, TG227]
# Silicon dioxide NM200                                              [TG208, TG227]
# Silicon dioxide NM201                                              [TG208, TG227]
# Silicon dioxide NM202                                              [TG208, TG227]
# Silicon dioxide NM203                                              [TG208, TG227]
# Silicon dioxide NM204                                              [TG208, TG227]
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...                 [TG208, TG227]
# Dendrimers                                                         [TG208, TG227]
# Nanoclays                                                          [TG208, TG227]
# Gold nanoparticles                                                 [TG208, TG227]
#
#                                                     ... Adsorption/desorption  \
# Fullerenes (C60)                                    ...                    []
# Single-walled carbon nanotubes (SWCNTs)             ...                    []
# Multi-walled carbon nanotubes (MWCNTs)              ...                    []
# Silver nanoparticles                                ...                    []
# Titanium dioxide NM105                              ...                    []
# Titanium dioxide NM100                              ...                    []
# Titanium dioxide NM101                              ...                    []
# Titanium dioxide NM102                              ...                    []
# Titanium dioxide NM103                              ...                    []
# Titanium dioxide NM104                              ...                    []
# Cerium oxide                                        ...                    []
# Zinc oxide                                          ...                    []
# Silicon dioxide NM200                               ...                    []
# Silicon dioxide NM201                               ...                    []
# Silicon dioxide NM202                               ...                    []
# Silicon dioxide NM203                               ...                    []
# Silicon dioxide NM204                               ...                    []
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...  ...                    []
# Dendrimers                                          ...                    []
# Nanoclays                                           ...                    []
# Gold nanoparticles                                  ...                    []
#
#                                                    Additional toxicological information  \
# Fullerenes (C60)                                                                     []
# Single-walled carbon nanotubes (SWCNTs)                                              []
# Multi-walled carbon nanotubes (MWCNTs)                                               []
# Silver nanoparticles                                                                 []
# Titanium dioxide NM105                                                               []
# Titanium dioxide NM100                                                               []
# Titanium dioxide NM101                                                               []
# Titanium dioxide NM102                                                               []
# Titanium dioxide NM103                                                               []
# Titanium dioxide NM104                                                               []
# Cerium oxide                                                                         []
# Zinc oxide                                                                           []
# Silicon dioxide NM200                                                                []
# Silicon dioxide NM201                                                                []
# Silicon dioxide NM202                                                                []
# Silicon dioxide NM203                                                                []
# Silicon dioxide NM204                                                                []
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...                                   []
# Dendrimers                                                                           []
# Nanoclays                                                                            []
# Gold nanoparticles                                                                   []
#
#                                                    Additional physico-chemical information  \
# Fullerenes (C60)                                                                        []
# Single-walled carbon nanotubes (SWCNTs)                                                 []
# Multi-walled carbon nanotubes (MWCNTs)                                                  []
# Silver nanoparticles                                                                    []
# Titanium dioxide NM105                                                                  []
# Titanium dioxide NM100                                                                  []
# Titanium dioxide NM101                                                                  []
# Titanium dioxide NM102                                                                  []
# Titanium dioxide NM103                                                                  []
# Titanium dioxide NM104                                                                  []
# Cerium oxide                                                                            []
# Zinc oxide                                                                              []
# Silicon dioxide NM200                                                                   []
# Silicon dioxide NM201                                                                   []
# Silicon dioxide NM202                                                                   []
# Silicon dioxide NM203                                                                   []
# Silicon dioxide NM204                                                                   []
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...                                      []
# Dendrimers                                                                              []
# Nanoclays                                                                               []
# Gold nanoparticles                                                                      []
#
#                                                    Additional information onenvironmentalfateand behaviour  \
# Fullerenes (C60)                                                                                   []
# Single-walled carbon nanotubes (SWCNTs)                                                            []
# Multi-walled carbon nanotubes (MWCNTs)                                                             []
# Silver nanoparticles                                                                               []
# Titanium dioxide NM105                                                                             []
# Titanium dioxide NM100                                                                             []
# Titanium dioxide NM101                                                                             []
# Titanium dioxide NM102                                                                             []
# Titanium dioxide NM103                                                                             []
# Titanium dioxide NM104                                                                             []
# Cerium oxide                                                                                       []
# Zinc oxide                                                                                         []
# Silicon dioxide NM200                                                                              []
# Silicon dioxide NM201                                                                              []
# Silicon dioxide NM202                                                                              []
# Silicon dioxide NM203                                                                              []
# Silicon dioxide NM204                                                                              []
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...                                                 []
# Dendrimers                                                                                         []
# Nanoclays                                                                                          []
# Gold nanoparticles                                                                                 []
#
#                                                    Additional information on residuechemistry  \
# Fullerenes (C60)                                                                           []
# Single-walled carbon nanotubes (SWCNTs)                                                    []
# Multi-walled carbon nanotubes (MWCNTs)                                                     []
# Silver nanoparticles                                                                       []
# Titanium dioxide NM105                                                                     []
# Titanium dioxide NM100                                                                     []
# Titanium dioxide NM101                                                                     []
# Titanium dioxide NM102                                                                     []
# Titanium dioxide NM103                                                                     []
# Titanium dioxide NM104                                                                     []
# Cerium oxide                                                                               []
# Zinc oxide                                                                                 []
# Silicon dioxide NM200                                                                      []
# Silicon dioxide NM201                                                                      []
# Silicon dioxide NM202                                                                      []
# Silicon dioxide NM203                                                                      []
# Silicon dioxide NM204                                                                      []
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...                                         []
# Dendrimers                                                                                 []
# Nanoclays                                                                                  []
# Gold nanoparticles                                                                         []
#
#                                                    Additional ecotoxicological information  \
# Fullerenes (C60)                                                                        []
# Single-walled carbon nanotubes (SWCNTs)                                                 []
# Multi-walled carbon nanotubes (MWCNTs)                                                  []
# Silver nanoparticles                                                                    []
# Titanium dioxide NM105                                                                  []
# Titanium dioxide NM100                                                                  []
# Titanium dioxide NM101                                                                  []
# Titanium dioxide NM102                                                                  []
# Titanium dioxide NM103                                                                  []
# Titanium dioxide NM104                                                                  []
# Cerium oxide                                                                            []
# Zinc oxide                                                                              []
# Silicon dioxide NM200                                                                   []
# Silicon dioxide NM201                                                                   []
# Silicon dioxide NM202                                                                   []
# Silicon dioxide NM203                                                                   []
# Silicon dioxide NM204                                                                   []
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...                                      []
# Dendrimers                                                                              []
# Nanoclays                                                                               []
# Gold nanoparticles                                                                      []
#
#                                                    Acute toxicity: other routes  \
# Fullerenes (C60)                                                             []
# Single-walled carbon nanotubes (SWCNTs)                                      []
# Multi-walled carbon nanotubes (MWCNTs)                                       []
# Silver nanoparticles                                                         []
# Titanium dioxide NM105                                                       []
# Titanium dioxide NM100                                                       []
# Titanium dioxide NM101                                                       []
# Titanium dioxide NM102                                                       []
# Titanium dioxide NM103                                                       []
# Titanium dioxide NM104                                                       []
# Cerium oxide                                                                 []
# Zinc oxide                                                                   []
# Silicon dioxide NM200                                                        []
# Silicon dioxide NM201                                                        []
# Silicon dioxide NM202                                                        []
# Silicon dioxide NM203                                                        []
# Silicon dioxide NM204                                                        []
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...                           []
# Dendrimers                                                                   []
# Nanoclays                                                                    []
# Gold nanoparticles                                                           []
#
#                                                            Acute toxicity: oral  \
# Fullerenes (C60)                                    [TG401, TG420, TG423,TG425]
# Single-walled carbon nanotubes (SWCNTs)             [TG401, TG420, TG423,TG425]
# Multi-walled carbon nanotubes (MWCNTs)              [TG401, TG420, TG423,TG425]
# Silver nanoparticles                                [TG401, TG420, TG423,TG425]
# Titanium dioxide NM105                              [TG401, TG420, TG423,TG425]
# Titanium dioxide NM100                              [TG401, TG420, TG423,TG425]
# Titanium dioxide NM101                              [TG401, TG420, TG423,TG425]
# Titanium dioxide NM102                              [TG401, TG420, TG423,TG425]
# Titanium dioxide NM103                              [TG401, TG420, TG423,TG425]
# Titanium dioxide NM104                              [TG401, TG420, TG423,TG425]
# Cerium oxide                                        [TG401, TG420, TG423,TG425]
# Zinc oxide                                          [TG401, TG420, TG423,TG425]
# Silicon dioxide NM200                               [TG401, TG420, TG423,TG425]
# Silicon dioxide NM201                               [TG401, TG420, TG423,TG425]
# Silicon dioxide NM202                               [TG401, TG420, TG423,TG425]
# Silicon dioxide NM203                               [TG401, TG420, TG423,TG425]
# Silicon dioxide NM204                               [TG401, TG420, TG423,TG425]
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...  [TG401, TG420, TG423,TG425]
# Dendrimers                                          [TG401, TG420, TG423,TG425]
# Nanoclays                                           [TG401, TG420, TG423,TG425]
# Gold nanoparticles                                  [TG401, TG420, TG423,TG425]
#
#                                                    Acute toxicity: inhalation  \
# Fullerenes (C60)                                        [TG403, TG433, TG436]
# Single-walled carbon nanotubes (SWCNTs)                 [TG403, TG433, TG436]
# Multi-walled carbon nanotubes (MWCNTs)                  [TG403, TG433, TG436]
# Silver nanoparticles                                    [TG403, TG433, TG436]
# Titanium dioxide NM105                                  [TG403, TG433, TG436]
# Titanium dioxide NM100                                  [TG403, TG433, TG436]
# Titanium dioxide NM101                                  [TG403, TG433, TG436]
# Titanium dioxide NM102                                  [TG403, TG433, TG436]
# Titanium dioxide NM103                                  [TG403, TG433, TG436]
# Titanium dioxide NM104                                  [TG403, TG433, TG436]
# Cerium oxide                                            [TG403, TG433, TG436]
# Zinc oxide                                              [TG403, TG433, TG436]
# Silicon dioxide NM200                                   [TG403, TG433, TG436]
# Silicon dioxide NM201                                   [TG403, TG433, TG436]
# Silicon dioxide NM202                                   [TG403, TG433, TG436]
# Silicon dioxide NM203                                   [TG403, TG433, TG436]
# Silicon dioxide NM204                                   [TG403, TG433, TG436]
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...      [TG403, TG433, TG436]
# Dendrimers                                              [TG403, TG433, TG436]
# Nanoclays                                               [TG403, TG433, TG436]
# Gold nanoparticles                                      [TG403, TG433, TG436]
#
#                                                    Acute toxicity: dermal
# Fullerenes (C60)                                                  [TG402]
# Single-walled carbon nanotubes (SWCNTs)                           [TG402]
# Multi-walled carbon nanotubes (MWCNTs)                            [TG402]
# Silver nanoparticles                                              [TG402]
# Titanium dioxide NM105                                            [TG402]
# Titanium dioxide NM100                                            [TG402]
# Titanium dioxide NM101                                            [TG402]
# Titanium dioxide NM102                                            [TG402]
# Titanium dioxide NM103                                            [TG402]
# Titanium dioxide NM104                                            [TG402]
# Cerium oxide                                                      [TG402]
# Zinc oxide                                                        [TG402]
# Silicon dioxide NM200                                             [TG402]
# Silicon dioxide NM201                                             [TG402]
# Silicon dioxide NM202                                             [TG402]
# Silicon dioxide NM203                                             [TG402]
# Silicon dioxide NM204                                             [TG402]
# Silicon dioxide JP AIST data on SiO2 UFP-80 and...                [TG402]
# Dendrimers                                                        [TG402]
# Nanoclays                                                         [TG402]
# Gold nanoparticles                                                [TG402]
#
# [21 rows x 132 columns]
